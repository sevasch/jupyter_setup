# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# referencing data relative to this notebook
import sys
sys.path.append("../../")  # when moving this file, adjust this

# general imports
import numpy as np
import matplotlib.pyplot as plt

# to export plots as vector graphics
from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('png', 'pdf') # uncomment to use vector graphics

# use matplotlib stylesheet
plt.style.use("./.mplstyle")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Title 1
#
# Text.
#
# ## Subtitle 1
#
# Text.
#
# $formula$
#
# ## Subtitle 2

# %%
x = np.linspace(-np.pi, np.pi, 1000)
y = np.sin(x) + np.random.normal(loc=0.0, scale=0.1, size=x.shape[0])

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x, y, label="data")
ax.set_xlabel("x axis"), ax.set_ylabel("y axis")
ax.legend()
fig.tight_layout()
